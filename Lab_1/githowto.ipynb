# %% [markdown]
# 13.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 12.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 11.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 10.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 9.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 8.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6.

# %%
git add a.html
git add b.html
git commit -m "Changes for a and b"
git add c.html
git commit -m "Unrelated change to c"

# %% [markdown]
# 5.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.

# %% [markdown]
# ![image.png](attachment:image.png)
